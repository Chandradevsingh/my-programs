# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1-20)')

# %%
len(simpsons)
# Out:
# 23

# %%
simpsons[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# 9            10             10                  "Homer's Night Out"
# 10           11             11                "The Crepes of Wrath"
# 11           12             12                 "Krusty Gets Busted"
# 12           13             13             "Some Enchanted Evening"
#
#                            Directed by  \
# 0                      David Silverman
# 1                      David Silverman
# 2                           Wes Archer
# 3       Gregg Vanzo & Kent Butterworth
# 4                      David Silverman
# 5                           Wes Archer
# 6                           Wes Archer
# 7                           Rich Moore
# 8                      David Silverman
# 9                           Rich Moore
# 10            Wes Archer & Milton Gray
# 11                           Brad Bird
# 12  David Silverman & Kent Butterworth
#
#                                            Written by  Original air date  \
# 0                                           Mimi Pond  December 17, 1989
# 1                                           Jon Vitti   January 14, 1990
# 2                      Jay Kogen & Wallace Wolodarsky   January 21, 1990
# 3                                Al Jean & Mike Reiss   January 28, 1990
# 4                                   John Swartzwelder   February 4, 1990
# 5                                Al Jean & Mike Reiss  February 11, 1990
# 6                                   John Swartzwelder  February 18, 1990
# 7      Al Jean, Mike Reiss, Sam Simon & Matt Groening  February 25, 1990
# 8                                   John Swartzwelder     March 18, 1990
# 9                                           Jon Vitti     March 25, 1990
# 10  George Meyer, Sam Simon, John Swartzwelder & J...     April 15, 1990
# 11                     Jay Kogen & Wallace Wolodarsky     April 29, 1990
# 12                          Matt Groening & Sam Simon       May 13, 1990
#
#    Prod. code U.S. viewers (millions)
# 0        7G08                26.7[47]
# 1        7G02                24.5[47]
# 2        7G03                27.5[48]
# 3        7G04                20.2[49]
# 4        7G05                27.1[50]
# 5        7G06                27.4[51]
# 6        7G09                27.6[52]
# 7        7G07                28.0[53]
# 8        7G11                33.5[54]
# 9        7G10                30.3[55]
# 10       7G13                31.2[56]
# 11       7G12                30.4[57]
# 12       7G01                27.1[58]

# %%
df_premier22 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E0.csv')

# %%
df_premier22
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 301  E0  15/04/2023  15:00          Wolves      Brentford     2     0   H
# 302  E0  15/04/2023  17:30        Man City      Leicester     3     1   H
# 303  E0  16/04/2023  14:00        West Ham        Arsenal     2     2   D
# 304  E0  16/04/2023  16:30   Nott'm Forest     Man United     0     2   A
# 305  E0  17/04/2023  20:00           Leeds      Liverpool     1     6   A
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0       0     1  ...     1.76  0.50      2.09      1.84   2.04   1.88
# 1       1     0  ...     2.73  1.75      1.90      2.03   1.91   2.02
# 2       1     0  ...     1.76  0.50      1.93      2.00   1.93   2.00
# 3       1     1  ...     1.87 -0.25      2.08      1.85   2.10   1.84
# 4       0     0  ...     1.89 -1.00      1.97      1.96   1.99   1.93
# ..    ...   ...  ...      ...   ...       ...       ...    ...    ...
# 301     1     0  ...     1.66  0.00      2.00      1.90   2.02   1.91
# 302     3     0  ...     3.19 -2.25      1.92      1.98   1.94   1.96
# 303     1     2  ...     2.12  1.00      1.89      2.04   1.88   2.05
# 304     0     1  ...     2.12  0.75      2.02      1.91   2.02   1.91
# 305     0     2  ...     2.61  0.75      2.01      1.89   2.01   1.92
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.09     1.88     2.03     1.85
# 1       2.01     2.06     1.89     1.99
# 2       1.94     2.04     1.88     2.00
# 3       2.14     1.87     2.08     1.81
# 4       2.19     1.97     2.03     1.86
# ..       ...      ...      ...      ...
# 301     2.04     1.95     1.97     1.89
# 302     1.95     2.08     1.86     2.00
# 303     1.97     2.11     1.85     2.03
# 304     2.09     1.92     1.99     1.88
# 305     2.12     1.94     2.00     1.86
#
# [306 rows x 106 columns]

# %%
df_premier22.rename(columns={'FTHG' : 'home_goals',
                             'FTAG' : 'away_goals'}, inplace=True)

# %%
df_premier22
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  home_goals  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal           0
# 1    E0  06/08/2022  12:30          Fulham      Liverpool           2
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa           2
# 3    E0  06/08/2022  15:00           Leeds         Wolves           2
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest           2
# ..   ..         ...    ...             ...            ...         ...
# 301  E0  15/04/2023  15:00          Wolves      Brentford           2
# 302  E0  15/04/2023  17:30        Man City      Leicester           3
# 303  E0  16/04/2023  14:00        West Ham        Arsenal           2
# 304  E0  16/04/2023  16:30   Nott'm Forest     Man United           0
# 305  E0  17/04/2023  20:00           Leeds      Liverpool           1
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0             2   A     0     1  ...     1.76  0.50      2.09      1.84
# 1             2   D     1     0  ...     2.73  1.75      1.90      2.03
# 2             0   H     1     0  ...     1.76  0.50      1.93      2.00
# 3             1   H     1     1  ...     1.87 -0.25      2.08      1.85
# 4             0   H     0     0  ...     1.89 -1.00      1.97      1.96
# ..          ...  ..   ...   ...  ...      ...   ...       ...       ...
# 301           0   H     1     0  ...     1.66  0.00      2.00      1.90
# 302           1   H     3     0  ...     3.19 -2.25      1.92      1.98
# 303           2   D     1     2  ...     2.12  1.00      1.89      2.04
# 304           2   A     0     1  ...     2.12  0.75      2.02      1.91
# 305           6   A     0     2  ...     2.61  0.75      2.01      1.89
#
#      PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.04   1.88     2.09     1.88     2.03     1.85
# 1     1.91   2.02     2.01     2.06     1.89     1.99
# 2     1.93   2.00     1.94     2.04     1.88     2.00
# 3     2.10   1.84     2.14     1.87     2.08     1.81
# 4     1.99   1.93     2.19     1.97     2.03     1.86
# ..     ...    ...      ...      ...      ...      ...
# 301   2.02   1.91     2.04     1.95     1.97     1.89
# 302   1.94   1.96     1.95     2.08     1.86     2.00
# 303   1.88   2.05     1.97     2.11     1.85     2.03
# 304   2.02   1.91     2.09     1.92     1.99     1.88
# 305   2.01   1.92     2.12     1.94     2.00     1.86
#
# [306 rows x 106 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import camelot
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\camelot\__init__.py:6
#       3 import logging
#       5 from .__version__ import __version__
# ----> 6 from .io import read_pdf
#       7 from .plotting import PlotMethods
#      10 # set up logging
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\camelot\io.py:5
#       1 # -*- coding: utf-8 -*-
#       3 import warnings
# ----> 5 from .handlers import PDFHandler
#       6 from .utils import validate_input, remove_extra
#       9 def read_pdf(
#      10     filepath,
#      11     pages="1",
#    (...)
#      16     **kwargs
#      17 ):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\camelot\handlers.py:9
#       6 from pypdf import PdfReader, PdfWriter
#       8 from .core import TableList
# ----> 9 from .parsers import Stream, Lattice
#      10 from .utils import (
#      11     TemporaryDirectory,
#      12     get_page_layout,
#    (...)
#      16     download_url,
#      17 )
#      20 class PDFHandler(object):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\camelot\parsers\__init__.py:4
#       1 # -*- coding: utf-8 -*-
#       3 from .stream import Stream
# ----> 4 from .lattice import Lattice
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\camelot\parsers\lattice.py:25
#      14 from ..core import Table
#      15 from ..utils import (
#      16     scale_image,
#      17     scale_pdf,
#    (...)
#      23     compute_whitespace,
#      24 )
# ---> 25 from ..image_processing import (
#      26     adaptive_threshold,
#      27     find_lines,
#      28     find_contours,
#      29     find_joints,
#      30 )
#      31 from ..backends.image_conversion import BACKENDS
#      34 logger = logging.getLogger("camelot")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\camelot\image_processing.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 import cv2
#       4 import numpy as np
#       7 def adaptive_threshold(imagename, process_background=False, blocksize=15, c=-2):
#
# ModuleNotFoundError: No module named 'cv2'
