# %% [markdown]
# # Variables And Expressions :
#                     An expression in python is anything that results in a value.
# #Statement :
#         A statement in python is something that results in an action or execution of a command. There is no calculation per se or any sort of manipulation.
#
#
# #Variable :
#         #Rules for Declaring Variable Names :
#                           1. We can not start a variable name with a number.
#                           so if i were to give a variable name 4num
#                           2. We are not allowed to use any non-alpha numeric character except underscore (_) character while naming our variables.
#                           3. Variables names are case-sensitive.
#                           4. We can not use reserved words.
#                           python has a bunch of reserved words these words essentially are performed or they are
#                           used to perform certain special function and are used are identifiers for certain special functions
#                           in python. These words have a special purpose like that perticular has a special purpose within the python programming language and we can not use them to name our variables.
#                           Variables are treated more like references or pointers instead of containers.
#                           Let's move on to a concept where we try to really understand what do we mean by
#                           storing data inside a variable. when i say we are storing something inside a variable.
#                           you get an image or you get an idea in your head that this variable is like a container where we store or we put a perticular object inside it. Does that mean that
#                           variables have a place in the memory are they also an object that is placed in the memory where we can put other objects inside of well i'll show you an example where this idea is disproven or where i'll show you this idea is kind of different than what we understand by storing something inside a variable now let's say i'm storing the same object i will take this object some random number let's say 100 and i'm going to store it into two different variables. So i take x is equal to 100 over here and in the next line i'll store 100 in y as well. Now objects were i mean if variables were objects that we placed in our system then x and y should have two
#                           different ids but let's see what happens when i check the id of x and id of y
#                           they should be different in case variables were their own objects however as you can see the id of x and id of y are exactly the same.
#                           orphaned object.
#                           Objects :
#                           All the data in a python code is represented by objects or by relations between objects. Any form of data that can be manipulated is called on object in python.
#                           Numbers such as 50 or text data like 'Hello' or even lists like ['eggs', 'apples', 'oranges'] are all types of objects.
#                           The following image gives a nice pictorial representation into classification of some most commonly encountered objects in python.There are three important properties associated with every object in python :
#                                 - Type
#                                 - Identity
#                                 - Value
#                         #Identity - can be considered to be the address to be the address in the memory where the object is stored. An object identity never changes once it has been created.
#                         is operator compares the identity of two objects. id() function returns an integer representing its identity.
#
#                         #Type - An object's type defines the possible values and operations that it supports. The type function returns the type of an object. An object type is unchangeable like the identity.
#
#                         #Value - Value is the data actually contained in the object. For example, it is a trext data stored in string objects or the numerical itself in the case of integer objects.
#
#                         The value of some objects can change. Objects whose value can change are said to be mutable. Objects whose value is unchangeable once they are created are called immutable.
#
#                           #Python Object Types :
#                                                 All the data that we manipulate or use in our operations in our code are represented as objects or relations between objects

# %%
a = 100
#4num = "Hello"
num4 = "Hello"
num_4 = 'random'
#This would be perfectly fine. I won't get an error.
#num-4 = 'random'
Num = 50
NUM = 60
x = 100
y = 100
id(x)
id(y)
id('hello')
type('hello')
type(50)

# %%
a

# %%
X = "Hello"

# %%
X

# %%
type('hello')

# %%
type(50)

# %% [markdown]
# #Type Conversion Numeric Data Type :
#                             1. Integer
#                             2. Float
#                             3. Complex
#
#                             Type conversion refers to the conversion of an object from one data type to another.
#                             eg. : string to integer.
#                             We can use the int(a, base) function to convert something to an int. Here a is the object we wish to convert to a decimal and base is the base in which a is supposed to be interpreted as. By default it is assumed it is in decimal.
#                             str(a)
#                             float(a)
#                             oct(a)
#                             hex(a)
#                             complex(a,b)
#                             tuple(a)
#                             list(a)
#                             set(a)

# %%
#Complex Number
3 + 7j#(The imaginary component is 7) All complex numbers have a real and imaginary component. This is how we denote them.

# %%
x = '145'
x
type(x)
y = int(x)
y
type(y)
z = float(y)
o = oct(y)
h = hex(y)
s = str(y)
z
o
h
s
complex = complex(5,2.3)
complex

# %%
tuple('random')
list('random')
set('random')
dict(string='random')

# %% [markdown]
# Python Strings :
#             Strings is an object type in python that is actually a subtype of a broader classification of object type called sequences. Sequences are objects that contain components one after the other. where each object is given a numeric index which identifies that component and its position within the whole sequence. As python is a zero index based language. The first index of any object is always indexed 0.
#             #Defining strings :
#                             Strings are always defined using opening and closing delimiters. These delimiters are pairs of single or double quotes.
#             Strings in python are object type to store textual data.
#             #How are strings sequences?
#                     Any component within a string can be referenced by entering an index within square brackets.
#                     So naturally this must work for a string. Let's try :

# %%
print('this is a string')
print("this is also a string")
test = 'random' #random test string assigned to variable called test.
test[5] #retieving the 0th index component of a string.
#retrieving the component at index 0 retrieved the first character of our string 'random'. From this we can see every string is a sequence of single character strings joined together to give us our main string.

# %% [markdown]
# #String operations and Functions :
#                     1. We can retrieve indivisual elements of a string using indexes.
#                     2. We can check which position a particular character is holding, using the index() method in string class object.
#                     3. Using the split() function we can split up a string into smaller strings and place them into lists. what we enter in the brackets in the split() function is used as a demarker from where to split the string up. By default if nothing is entered into it, it uses blank space as the demarker.
#                     4. We can concatenate two strings using the + symbol.

# %%
test = 'random'
test.index('d') #checking where is the character d in the str object.
#We can also slice a string and retrieve a part of it.
test[0:6]
test[::2]
test[-1]
test[-6:6]
test = 'UPPERlower'
test.upper()
test.lower()
test = "hello world!"
test.split()#using the split() function we can split up a string into smaller strings and place them into lists. what we enter in the brackets in the split() function is used as a demarker from where to split the string up. By default if nothing is entered into it, it uses blank space as the demarker.
print('first'+'second')

# %% [markdown]
# #Escape Sequences :
#                 Escape sequences are special commands that tell python to either:
#                 1. Supress special meaning of some character or symbol in a string.
#                 Escape sequences are defined using the escape character.(Escape character - Backslash \)
#                 2. Otherwise, give a character or symbol a special meaning.
#                 (\t for tabbed space and \n for a line break.)

# %%
print('It\'s my birthday')
print('there is a \t space')
print('first line.\nsecond line.')

# %% [markdown]
# #Python Lists and Tuples :
#                     #Lists - In short, list is a collection of arbitrary objects. somewhat akin to an array in other programming languages but more flexible.
#                     Python lists are a type of sequence. Each object in a list is assigned an index as a typical for all sequences. These objects can be manipulated using its respective index.
#                     #Defing lists:
#                     a = [1,2,3]
#                     #Feautures of Python Lists
#                     1. Lists are ordered.
#                     2. Lists are mutable.
#                     3. Lists are Dynamic.(What does this mean is that as we are making or as we are prgramming we can make changes to an already created list. as we are programming without having to go through a compilation stage, so if we had to increase the or we had to add cerain elements to an already created list the original list grows in size to accommodate these new elements.)
#                     4. Lists can contain arbitrary objects.
#                     5. Lists can be nested to arbitrary depth.
#                     #List Operations :
#                                 1. List elements can be accessed using respective index.
#                                 2. Lsts can be sliced using strides.
#                                 3. Lists can be concatenated and replicated.
#                                 3. Lists can be appended and prepended.

# %%
a = [1,2,3]
a = [1,2,3]
b = [2,1,3]
a is b
a = [1,2,3,4,5,6,'strings']
a = [1,2,3,[4,5,6,[7,8,9]]]
a = [1,2,3,4,5,6]
a[3]
a[1:4]
a[1:4:2]
a[-1]
a[-2]
a[::-1]
a+[7,8,9]
a = [0]+a
a*2
a*3

# %%
b = ['eggs', 'apples', 'carrot', 1, 2, 3, 4, 5]
b[1] = 'orange'
b[1:3] = ['banana', 'cabbage']
b[1:3] = ['kiwi', 'orange', 'sponge']
b[0:3] = ['wine']
b[1:2] = [0]
b

# %%
#List Methods :
a = [1,2,3]
a.append(4)
a.append([5,6,7])
a.extend([8,9,10])
a.remove(8)
a.pop()
a.pop(4)
a

# %% [markdown]
# #Tuples :
#     Tuples are another ordered collection of objects like lists, except for two properties where they differ :
#         1. Tuples are immutable.
#         2. Tuples are defined using parenthesis instead of square brackets.
#         #Why use tuples over lists?
#         1. Program execution is faster when manipulating Tuples.
#         2. Another datatype in python called dictionaries, needs an immutable component lists can't be used there.
#         3. Tuples are more ifficient if you want to create an ordered list of objects that doesn't need modifications.
#         #Tuples packing and unpacking.

# %%
t = (1,2,3, 'cat')
x = (1,)
t[1:3]
t
t[::-1]
t = (1,2,3,4) #packing into t
(a,b,c,d) = t#unpacking into t
a
b
c
d
x,y,z = 1,2,3
x
y
z
x,z
y,z
x,y

# %% [markdown]
# #Dictionaries :
#         Dictionaries are another type of composite data types in python and also a collection of objects much like lists ans tuples. Like lists they are mutable, dynamic and can be nested. However a key difference is that dictionaries are unordered.
#         Also items in dictionaries are paired using keys unlike in lists and tuples where each item is assigned an index.
# #Defining a dictionary :
#                 #A dictionary is defined within curly braces. Each key-value pair is seperated using commas. The key and values are seperated using a colon.
#                 #Dictionary keys must be of an immutable data type. Duplicate keys not allowed. No such restriction on values.

# %%
d = {'banana':'yellow', 'apple':'red', 'grape':'green'}
d
type(d)

# %%
d = dict([('banana','yellow'), ('apple','red'), ('grape','green')])
d
#Note : Dictionary keys must be of an immutable data type. Duplicate keys not allowed. No such restriction on values.
#Dictionary operations and functions : 
#using keys
d['banana'] #accessing the value paired with the key banana
d['banana'] = 'gold' #changing the value associated to a perticular key in d
d
#using functions :
d.get('apple')
d['watermelon'] = 'red'
d   
del d['watermelon']
d
#you can probably draw parallels in how we use indexes when it comes to lists and tuples and even strings and how we use keys when it comes to dictionaries. They are quit similiar.

# %%
d = {'banana': 'gold', 'apple': 'red', 'grape': 'green'}
d.get('apple')
d.items()
d.keys()
d.values()
d.popitem()
d
x = dict([('kiwi','green'),('mango','yellow')])
x
d.update(x)
d

# %% [markdown]
# #Python Type Hierarchy(Data Model) :
#                             (But it's safe to say will still form the core what we call python standard type hierarchy.)
#                             1. None - Single object with this value. Accessed through build-in name 'None'. Truth value is false.
#                             2. Ellipsis - Single object with this value. Accessed through the build-in name 'Ellipses'. It is used to indicate the presence of the '_' syntax in a slice. It's truth value is true.
#                             3. Numbers - Immutable. created through numeric literals and outputs of arithmatic expressions and arithmatic built-in functions. Subtypes :
#                                 @Integers
#                                 a. Plain Integers - These represents numbers in the range -2147483648 to 2147483647.
#                                 b. Long Integers - These represent numbers in unlimited range. subject to available(virtual) memory.
#                                 @Floating Point Numbers - These represent machine-level double precision floating point numbers.
#                                 @Complex Numbers - These represent complex numbers as a pair of machine-level double precision floating point numbers.
#                             4. Sequences - These represents finite ordered sets indexed by natural numbers. Subtypes are basically on mutability.
#                                 a. Immutable Sequences -
#                                     @Strings - The items of a string are characters.
#                                     @Unicode - The items of a unicode object are unicode characters.
#                                     @Tuples - The items of a tuple are arbitrary python objects.
#                                 b. Mutable Sequences -
#                                    @Lists - The item of a list are arbitrary python objects.
#                                 c. Mappings - These represent finite sets of objects indexed by arbitrary index sets.
#                                 d. dictionaries - These represents finite sets of objects indexed by nearly arbitrary values. These indexes must be of immutable data type.
#                             5. Callable types :
#                                         a. user-defined functions
#                                         b. user-defined methods
#                                         c. built-in functions
#                                         d. built-in methods
#                                         e. classes
#                                             @class instances
#                             6. Modules
#                             7. Files
#                             8. Internal types
#                             $Note : callable types as a whole are referenced using the call function.
#                             Modules or module objects essentially are referenced or called using the import function. Modules can be considered as these large libraries, larger pieces of code or application that contain various different methods and functions and objects and classes within them.
#                             Files are datatypes that are called using the open function.
#                             Finally there are internal types that are used by python interpreter. Agsin this is something that does not concern us right now. The interpreter for python uses these data types for its functioning.
#                             #Logical operations -
#                                         @logical and - It returns true if both the operands are true.   x and y
#                                         @logical or - It returnds true if either of the operand is true.    x or y
#                                         @logical not - It returns false if operand is true. not x
#                             #Comparision Operations -
#                             #Special Operators -
#                                         a. Identity operators - is and the is not operators.
#                                         b. Membership operators - in and not in operators.
#                             #Math Function in python -
#                             This math module is part of the basic python installation so you don't have to deal with

# %% [markdown]
# #Arithmatic Operations :
#                 In this video, I will show you some of categories of operations, that are possible in python.
#                 So let's start off. So the first category of operations are arithmatic operations.

# %%
# 5 + 6
# 5-3
# 5*2
# 8/2
# 9/2
# 9//2 #It returns us the largest whole number that is lesser than the result of our division.
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
#Finally, we have something, if you want to raise something to the power of something.
# 6**2#return first raised to power of second.
# 7%3
# a = True
# b = True
# a and b
# a = True
# b = False
# a or b
# a = 1001
# b = 1000 + 1
# a == b
# a is b
# type(a)
# type(b)
# id(a)
# id(b)
# import math
# math.pi#Pi is ratio of a circle circumference to its diameter.
# math.tau#Tau is the ratio of of a circle circumference to its radius. Tau is always two times the value of pi. This is by definotion and much like pi, if you call the tau constant from the math module. It will also return you a float number.
#Euler's Number(e) is the base of the natural logrithm.
# math.inf
# type(math.inf)
# -math.inf
# type(-math.inf)
# math.nan
# type(math.nan) #This really not a mathmatical constant. There is no constant in math not a number. This is a computer science related concept. It's used to denote invalid inputs or it's used to indicate a certain places where say a variable should have a number. It's been corrupted for whatever reason or now it has a text or symbol and our code throws an error. In these cases python excepts a number from us or from your code and it does not get it. It throw you a nan value. This is usually used in cases where you have errors in your code.

# %% [markdown]
# Arithmatic Functions :
#                 Common arithmatic functions that are available to us are factorial, the ceiling operation, floor operation, There's permutations, combinations, you can find the greatest common divisor or the gcd and the lcm or the least common multiple. And you can truncate numbers. Let's look at them one by one.

# %%
math.factorial(10) #Obviously factorials are only defined for positive integers. It's not defined for negative values. And uh It's also not defined for decimal values. So let's look at an example.
math.ceil(6.6)#It gives you the smallest number that is greater than  or equal to that you pass over here.
math.floor(6.6)#It gives you the largest number that is lesser than or equal to that you pass over here.
math.trunc(-7.5)#We pass a decimal value, a float number between the parenthesis and get back the number without the decimal component. It will chop away the remained part. It does the floor function for positive values and ceiling function for negative values. It rounds down and round up respectively for positive and negative values.
# math.perm(n,k)#n!/(n-k)!
# math.comb(n,k)#n!/((n-k)!*k!)
math.gcd(4,8)
math.lcm(4,8)
2**3
math.pow(2,3)#part of the math module.
pow(2,3)#part of the core(base) python.
math.exp(3)
initial = 100
time = 10
half_life = 3
remaining = initial*math.exp(-0.693*time/half_life)
math.log(8)
math.log(8,2)
math.log2(8)
math.log10(8)
math.sqrt(49)
# math.sin(3.14)#It requires values in radian not in degrees. As we know 3.14 is the approximation of the value pi. It's supposed to be zero. Again we get something close to zero.
# math.asin(3.14)#inverse of sine.
# #Same for hyperbolas
# math.sinh(50)
# math.asinh(50)#hyperbolic inverse of sine.

# %%
Conditional Statements in Python :

# %%
# if 50<30:
#         print('50 is indeed a larger number than 30')
# age = 20
# if age>18:
#         print('this person is an adult')
#This is how indentation is used in python. In other languages, we might use, but in python, we don't use indentation. Python the trademark language for indentation and programming. The general consenses is this that indentation helps make the code look very presentable and very readable. This is one of the facets of the python programming language.
#Multiple conditionals
#You can see what i'm doing in this piece of code.
# x = [50,'cat','apple']
# if 60 in x:
#     print('60 is in list x')
# elif'cat' in x:
#     print('cat is in list x')
# else:
#     print('this will not be printed')
# x = 'cat'
# if 50>60:
#     print('this won\'t get printed.')
# elif x == 'cat':
#     print('this is printed')
# elif 1/0:
#     print('nothing')
    #python Ternary Operator
age = 26
# x = 'adult' if age>18 else 'child'
# x
#i'm checking if age is greater than 18
if age>18:
    pass 
#While loop - Indefinite Iterations
        #Iteration means executing the same block of code over and over(many times). The programming structure that implements iteration is called a loop.
        @Indefinite Iterations
        @definite Iterations
#Example :
if <expression>
    <statment>
    <statment>
    <statment>
    <statment>
        while <expr>:
            <statement(s)>

# %%
n=0

while n<=5:
    print('value of n is =', n)
    n += 1
#And interestingly, we don't necessarily have to define these control variables always. We can use iterables.

# %%
# n
# a = [1,2,3,4,5]
# x = 1
# while a:
#     print('this is iteration number : ', x)
#     x += 1
#     print(a)
#     a.pop()
#Nested While Loop : While loop can have other control structures such as if statements or other while loop nested with them. This is a broad topic, Nested control structures. It is one of the great feature of python. That is very flexible in this way.
# a = [1,2,3,4,5]
# while a:
#     print('>', a.pop(0))
#     b = ['first', 'second']
#     while b:
#         print('>>>', b.pop(0))
        # And then, it goes back to the beginning to the expression. And the controlling expression is again re-evaluted and it is checked whether the loop will execute again or terminate.
        #Break and Continue : The break statement terminates the loop entirely. Once the break statement is found, the complete while loop that we are using completely terminated. And the continue statement terminates only the current loop iteration.
# n = 0
# while n<=5:
#     print('the value of n is :',n)
#     n += 1
#     if n == 2:
#         break
# n = 0
# while n<=5:
#     print('the value of n is :',n)
#     n += 1
#     if n == 2:
#         continue
#     print('hello')
#While loop project in Python :
#Write a program to calculate the factorial of number
# print('Enter number')
# number = int(input())
# number_entered = number
# fac = 1
# if number == 1:
#     result = 1
# else:
#     while number>=1:
#         fac=fac*number
#         number-=1
#         result=fac
# print('Factorial of {} is {}'.format(number_entered, result))
# count = int(input('How much fibonacci numbers would you like to generate?'))
# i=1
# if count==0:
#     fib=[]
# elif count==1:
#     fib=[1]
# elif count==2:
#     fib=[1,1]
# elif count>2:
#     fib=[1,1]
#     while i<(count-1):
#         fib.append(fib[i]+fib[i-1])
#         i+=1
# #print the series
# print(fib)
#It's going to keep adding each subsequent numbers, subsequent
#Write a program which takes two digits as input X and Y and generate two dimentions array :
#The element value in the i-th row and j-th column sould be i*j. Note: i=0,1...X-1;j=0,1...Y-1.
#Suppose the following inputs are given to the program: 3,5
#The of the program sould be:
#[[0,0,0,0,0],[0,1,2,3,4],[0,2,4,6,8]]
# input_string = input('Enter array dimensions(m, n)e.g. 3, 5')
# print(input_string)
# dimensions=[int(x) for x in input_string.split(",")]

# row_Num = dimensions[0]
# col_Num = dimensions[1]

# multilist = [[0 for col in range(col_Num)] for row in range(row_Num)]

# for row in range(row_Num):
#     for col in range(col_Num):
#         multilist[row][col]=row*col

# print(multilist)
#For loop in Python - Definite Iterations
#Iterables and Iterators :
#In python, iterable means an object can be used in iteration.
#If an object is an iteable, it can be passed to the built-in function iter(), which returns something called an iterator.
#Below is the syntax of a basic for loop in Python :
#for <var> in <iteable>:
#       <statement(s)>
#Before we see an example of for loop in python, let's first understand the concept of iteration and iterables.
#In python, collection of objects like dictionaries, sets, tuples and lists etc are all example of iterables.
# a = ['first', 'second', 'third', 'forth', 'fifth']
# iter_a = iter(a)
# iter_a
# a = ('first', 'second', 'third', 'forth', 'fifth')
# iter_a = iter(a)
# iter_a
# a = {'first', 'second', 'third', 'forth', 'fifth'}
# iter_a = iter(a)
# iter_a
# a = {'first': 1, 'second': 2, 'third': 3, 'forth': 4, 'fifth': 5}
# iter_a = iter(a)
# iter_a
#An iterator is essentially a value producer that yields successive values from its associated iterator object. The built-in function next() is used to obtain the next value from an iterator.
# a = ['first', 'second', 'third', 'forth', 'fifth']
# iter_a = iter(a)
# iter_a
# next(iter_a)
# next(iter_a)
# next(iter_a)
# next(iter_a)
# next(iter_a)
# next(iter_a)
# a = ['one', 'two', 'three', 'four', 'five']
# for x in a:
#         print(x)
#In the previous video you might have already seen some of the basic concepts surrounding if statements.
#If statements in Python :
#Python If-else statement
#The if-else statement is the staple of most programming languages. It is used to test different conditions and execute code accordingly.
#The basic syntax is as follows :
#if condition1 = True:
#       execute code1
#else:
#       execute code2
# x = 5
# if x>5:
#         print('X is larger than five!')
# else:
#         print('X is smaller than five!')
x = 5
if x==5:
        print('Hey X is exactly five!')
elif x>5:
        print('X is now more than five!')
else:
        print('X is now less than five!')
#Nested if-else statements
#File Handling In Python :
# Out:
# Hey X is exactly five!

# %%
#By default, Python source files are treated as encoded in UTF-8. In that encoding, characters of most languages in the world can be used simultaneously in string literals, identifiers and comments — although the standard library only uses ASCII characters for identifiers, a convention that any portable code should follow.
